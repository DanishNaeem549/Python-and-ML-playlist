# %%
# Function Copy 

def addition(a,b):
    return a+b

add=addition(10,20)
print(add)

# %%
def welcome():
    return "Welcome to Python Programming"


wel=welcome()
print(wel)
# Out:
# Welcome to Python Programming
