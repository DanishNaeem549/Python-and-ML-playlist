# %% [markdown]
# <a href="https://colab.research.google.com/github/DanishNaeem549/Python-and-ML-playlist/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv('/content/creditcard_2023.csv')
df.head()
# Out:
#    id        V1        V2        V3  ...       V27       V28    Amount  Class
# 0   0 -0.260648 -0.469648  2.496266  ... -0.081230 -0.151045  17982.10    0.0
# 1   1  0.985100 -0.356045  0.558056  ... -0.248052 -0.064512   6531.37    0.0
# 2   2 -0.260272 -0.949385  1.728538  ... -0.300258 -0.244718   2513.54    0.0
# 3   3 -0.152152 -0.508959  1.746840  ... -0.165316  0.048424   5384.44    0.0
# 4   4 -0.206820 -0.165280  1.527053  ...  0.023712  0.419117  14278.97    0.0
#
# [5 rows x 31 columns]

# %%
df.isna().sum()
# Out:
# id        0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
df.fillna(df.mean(), inplace= True)

# %%
df.isna().sum()
# Out:
# id        0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
x= df.drop(['id', 'Class'], axis=1)
y = df['Class']
y = y.astype(int)

# %%
x.head()
# Out:
#          V1        V2        V3  ...       V27       V28    Amount
# 0 -0.260648 -0.469648  2.496266  ... -0.081230 -0.151045  17982.10
# 1  0.985100 -0.356045  0.558056  ... -0.248052 -0.064512   6531.37
# 2 -0.260272 -0.949385  1.728538  ... -0.300258 -0.244718   2513.54
# 3 -0.152152 -0.508959  1.746840  ... -0.165316  0.048424   5384.44
# 4 -0.206820 -0.165280  1.527053  ...  0.023712  0.419117  14278.97
#
# [5 rows x 29 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
x_train.shape
# Out:
# (52902, 29)

# %%
y_train.shape
# Out:
# (52902,)

# %%
y_train.unique()
# Out:
# array([0, 1])

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42)
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, random_state=42)

# %%
model.score(x_train, y_train)
# Out:
# 0.9997920683528033

# %%
model.score(x_test, y_test)
# Out:
# 0.9992439135037048

# %%
y_prob = model.predict_proba(x_test)
y_prob
# Out:
# array([[9.99746532e-01, 2.53468430e-04],
#        [9.99991661e-01, 8.33907893e-06],
#        [9.99980273e-01, 1.97270765e-05],
#        ...,
#        [9.99992592e-01, 7.40817342e-06],
#        [9.99984447e-01, 1.55526188e-05],
#        [9.99805465e-01, 1.94535114e-04]])

# %%
cm = confusion_matrix(y_test, model.predict(x_test))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
classification_report(y_test, model.predict(x_test))
# Out:
# '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00     13186\n           1       0.97      0.78      0.86        40\n\n    accuracy                           1.00     13226\n   macro avg       0.98      0.89      0.93     13226\nweighted avg       1.00      1.00      1.00     13226\n'

# %%
accuracy_score(y_test, model.predict(x_test))
# Out:
# 0.9992439135037048
