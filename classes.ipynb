# %%
# class is blue print for creating objects

class car:
    pass



#object
audi = car()
bmw = car()

# %%
# instance variable


class Dog:
    def __init__(self,name, age):
        self.name=name
        self.age=age



Dog1=Dog("buddy",3)
print(Dog1.name)
print(Dog1.age)
# Out:
# buddy
# 3

# %%
# instance method

class Dog:
    def __init__(self,name, age):
        self.name=name
        self.age=age

    def bark(self):
        print(f"{self.name} says woof")




Dog1=Dog("buddy",3)
print(Dog1.name)
print(Dog1.age)
Dog1.bark()
# Out:
# buddy
# 3
# buddy says woof

# %%
# example



class Bankaccount:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print(f"{amount} is successfully deposit in your account total balance = {self.balance}")

    def withdraw(self, amount):
        self.balance -= amount
        print(f"{amount} is successfully withdraw from your account total balance = {self.balance}")






Danish = Bankaccount("Danish", 12000)
Danish.deposit(8000)
Danish.withdraw(6000)
# Out:
# 8000 is successfully deposit in your account total balance = 20000
# 6000 is successfully withdraw from your account total balance = 14000

# %%
# ATM

class ATM:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.balance = balance

    def deposit(self):
        amount = int(input("Enter amount :"))
        self.balance += amount
        print(f"{amount} is successfully deposit in your account total balance = {self.balance}")

    def withdraw(self):
        amount = int(input("Enter amount :"))
        self.balance -= amount
        print(f"{amount} is successfully withdraw from your account total balance = {self.balance}")



correct_password = "danish123"

try:
    password = input("Enter Password: ")

    if password != correct_password:
          raise Exception("Incorrect Password")

    else:
        D = ATM("Danish", 12000)
        print("Enter 1 for deposit")
        print("Enetr 2 for withdraw")
        num = int(input("Enter your option:"))

        if num==1:
            D.deposit()
        elif num == 2:
            D.withdraw()
        else:
            print("invalid option")


except Exception as e:
         print(e)
# Out:
# Enter 1 for deposit
# Enetr 2 for withdraw
# 3000 is successfully withdraw from your account total balance = 9000
