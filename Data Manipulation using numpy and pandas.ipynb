# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Practice.csv')

# %%
df.head(4)
# Out:
#    Order_ID Customer_ID        Date  Customer_Age  Gender        City  \
# 0  ORD10001    CUST1001  2024-01-01          56.0    Male      Lahore
# 1  ORD10002    CUST1002  2024-01-01          46.0  Female      Multan
# 2  ORD10003    CUST1003  2024-01-02          32.0    Male    Burewala
# 3  ORD10004    CUST1004  2024-01-03          60.0  Female  Gujranwala
#
#   Department     Product     Category  Quantity  Unit_Price  Discount_Percent  \
# 0         IT       Mouse       Office         6   105836.96              7.97
# 1         HR  Headphones       Office         7   196373.45             26.87
# 2      Sales      Webcam  Electronics         4    49330.30              3.10
# 3      Sales      Tablet  Electronics         1   205153.20             19.70
#
#   Payment_Method Order_Status  Rating  Delivery_Days  Employee_Experience  \
# 0           Cash    Completed     4.1            7.0                    1
# ...

# %%
df.tail(4)
# Out:
#      Order_ID Customer_ID        Date  Customer_Age  Gender        City  \
# 996  ORD10997    CUST1297  2026-07-28          43.0  Female      Multan
# 997  ORD10998    CUST1298  2026-07-29          21.0    Male    Burewala
# 998  ORD10999    CUST1299  2026-07-30          36.0  Female  Rawalpindi
# 999  ORD11000    CUST1300  2026-07-31          37.0  Female    Peshawar
#
#     Department     Product     Category  Quantity  Unit_Price  \
# 996  Marketing       Phone       Office         1    88959.78
# 997         IT  Headphones  Accessories         6   141366.22
# 998      Sales       Mouse  Electronics         5    63454.52
# 999  Marketing       Phone       Office         4   228864.84
#
#      Discount_Percent Payment_Method Order_Status  Rating  Delivery_Days  \
# 996             22.36       JazzCash    Completed     2.2            5.0
# 997             11.37  Bank Transfer     Returned     3.5            4.0
# ...

# %%
df.dtypes
# Out:
# Order_ID                   str
# Customer_ID                str
# Date                       str
# Customer_Age           float64
# Gender                     str
# City                       str
# Department                 str
# Product                    str
# Category                   str
# Quantity                 int64
# Unit_Price             float64
# Discount_Percent       float64
# Payment_Method             str
# Order_Status               str
# Rating                 float64
# Delivery_Days          float64
# Employee_Experience      int64
# Gross_Amount           float64
# Discount_Amount        float64
# Net_Amount             float64
# dtype: object

# %%
# Handling Missing Values

df.isnull()
# Out:
#      Order_ID  Customer_ID   Date  Customer_Age  Gender   City  Department  \
# 0       False        False  False         False   False  False       False
# 1       False        False  False         False   False  False       False
# 2       False        False  False         False   False  False       False
# 3       False        False  False         False   False  False       False
# 4       False        False  False         False   False  False       False
# ..        ...          ...    ...           ...     ...    ...         ...
# 995     False        False  False         False   False  False       False
# 996     False        False  False         False   False  False       False
# 997     False        False  False         False   False  False       False
# 998     False        False  False         False   False  False       False
# 999     False        False  False         False   False  False       False
#
#      Product  Category  Quantity  Unit_Price  Discount_Percent  \
# ...

# %%
df.isnull().sum()
# Out:
# Order_ID                0
# Customer_ID             0
# Date                    0
# Customer_Age           20
# Gender                  0
# City                    0
# Department              0
# Product                 0
# Category                0
# Quantity                0
# Unit_Price              0
# Discount_Percent       20
# Payment_Method          0
# Order_Status            0
# Rating                 20
# Delivery_Days          20
# Employee_Experience     0
# Gross_Amount            0
# Discount_Amount         0
# Net_Amount              0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Order_ID               False
# Customer_ID            False
# Date                   False
# Customer_Age            True
# Gender                 False
# City                   False
# Department             False
# Product                False
# Category               False
# Quantity               False
# Unit_Price             False
# Discount_Percent        True
# Payment_Method         False
# Order_Status           False
# Rating                  True
# Delivery_Days           True
# Employee_Experience    False
# Gross_Amount           False
# Discount_Amount        False
# Net_Amount             False
# dtype: bool

# %%
df['Order_Status'].fillna('Unknown', inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_32992\2026558767.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Order_Status'].fillna('Unknown', inplace=True)
# 0      Completed
# 1      Completed
# 2       Returned
# 3      Completed
# 4        Pending
#          ...
# 995    Completed
# 996    Completed
# ...

# %%
df['Order_Status']
# Out:
# 0      Completed
# 1      Completed
# 2       Returned
# 3      Completed
# 4        Pending
#          ...
# 995    Completed
# 996    Completed
# 997     Returned
# 998     Returned
# 999      Pending
# Name: Order_Status, Length: 1000, dtype: str

# %%
# rename a column

df.rename(columns={'Order_Status': 'Order_Status_Updated'}, inplace=True)

# %%
df
# Out:
#      Order_ID Customer_ID        Date  Customer_Age  Gender        City  \
# 0    ORD10001    CUST1001  2024-01-01          56.0    Male      Lahore
# 1    ORD10002    CUST1002  2024-01-01          46.0  Female      Multan
# 2    ORD10003    CUST1003  2024-01-02          32.0    Male    Burewala
# 3    ORD10004    CUST1004  2024-01-03          60.0  Female  Gujranwala
# 4    ORD10005    CUST1005  2024-01-04          25.0    Male     Karachi
# ..        ...         ...         ...           ...     ...         ...
# 995  ORD10996    CUST1296  2026-07-27          23.0  Female  Rawalpindi
# 996  ORD10997    CUST1297  2026-07-28          43.0  Female      Multan
# 997  ORD10998    CUST1298  2026-07-29          21.0    Male    Burewala
# 998  ORD10999    CUST1299  2026-07-30          36.0  Female  Rawalpindi
# 999  ORD11000    CUST1300  2026-07-31          37.0  Female    Peshawar
#
#     Department     Product     Category  Quantity  Unit_Price  \
# ...

# %%
# change the data type of a column

df['Order_Status_Updated'] = df['Order_Status_Updated'].astype('category')

# %%
df['Customer_Age'] = df['Customer_Age'].fillna(df['Customer_Age'].mean()).astype('int')
