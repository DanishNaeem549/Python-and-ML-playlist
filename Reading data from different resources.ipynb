# %%
import pandas as pd

# %%
import numpy as np

# %%
# read data from csv file link

df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.to_csv("titanic.csv", index=False)

# %%
# !pip install lxml
# !pip install html5lib
# !pip install beautifulsoup4

# %%
# read data from html file link

df1 = pd.read_html("https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/")

# %%
df1[0].sort_values(by='Closing Date', ascending=False, inplace=True)

# %%
df1[0]
