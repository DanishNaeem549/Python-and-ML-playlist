# %%
# conditional statement

x = 10
y = 20

if x > y:
    print("x is greater than y")
else:
    print("y is greater than x")
# Out:
# y is greater than x

# %%
age = int(input("Enter your age: "))

if age >= 18:
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote.")
# Out:
# You are eligible to vote.

# %%
number1= int(input("Enter a number: "))
number2= int(input("Enter another number: "))
number3= int(input("Enter a third number: "))
number4= int(input("Enter a fourth number: "))

if number1 > number2 and number1 > number3 and number1 > number4:
    print("The largest number is:", number1)
elif number2 > number3 and number2 > number4:
    print("The largest number is:", number2)
elif number3 > number4:
    print("The largest number is:", number3)
else:
    print("The largest number is:", number4)
# Out:
# The largest number is: 4

# %%
subject1 = int(input("Enter marks for subject 1: "))
subject2 = int(input("Enter marks for subject 2: "))
subject3 = int(input("Enter marks for subject 3: "))


total_marks = subject1 + subject2 + subject3
total_percentage = (total_marks / 300) * 100
percentage_subject1 = (subject1 / 100) * 100
percentage_subject2 = (subject2 / 100) * 100
percentage_subject3 = (subject3 / 100) * 100


if total_percentage >= 40 and percentage_subject1 >= 33 and percentage_subject2 >= 33 and percentage_subject3 >= 33:
    print("The student has passed all subjects.")
else:
    print("The student has not passed all subjects.")
# Out:
# The student has not passed all subjects.

# %%
username = input("Enter your username: ")
if len(username) < 10:
    print("Username must be at least 10 characters long.")
else:
    print("Username is contained more than 10 characters.")
# Out:
# Username is contained more than 10 characters.
