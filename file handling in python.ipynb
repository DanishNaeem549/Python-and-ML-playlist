# %%
# file writing 
with open('example.txt','w') as file:
  file.write('Hello world \n')
  file.write('file handling in python\n')
  file.write('welcome to Danish world')

# %%
# file reading
with open('example.txt', 'r') as f:
    print(f.read())
# Out:
# Hello world
# file handling in python
# welcome to Danish world

# %%
with open('example.txt', 'r') as f:
    print(f.readline())
    print(f.read(5))
# Out:
# Hello world
#
# file

# %%
# append in file

with open('example.txt','a') as f:
    f.write('\nPython is very important part for ai engineering')

# %%
# file reading
with open('example.txt', 'r') as f:
    print(f.read())
# Out:
# Hello world
# file handling in python
# welcome to Danish world
# Python is very important part for ai engineering
# Python is very important part for ai engineering

# %%
lines = [
    "Success starts with the decision to try.",
    "Every expert was once a beginner.",
    "Dream big. Start small. Act now.",
    "Discipline beats motivation every time.",
    "Progress is better than perfection.",
    "Stay focused; your future is watching.",
    "Great things take time.",
    "Hard work creates opportunities.",
    "Don't wait for chances—create them.",
    "Learn every day, improve every day.",
    "Failure is a lesson, not a destination.",
    "Small steps lead to big achievements.",
    "Confidence grows through action.",
    "Your only competition is yesterday's version of you.",
    "Success belongs to those who never quit.",
    "The best investment is in yourself.",
    "Build skills that no one can take away.",
    "Keep moving, even if it's one step at a time.",
    "The future rewards those who prepare today.",
    "Turn your ideas into reality."
]


with open('example.txt', 'a') as f:
    f.writelines(lines)

# %%
#example 
with open('example.txt','r') as f:
    content=f.read()

with open('destination.txt', 'w') as dest_f:
    dest_f.write(content)

# %%
#read and write binary files
line = b"\x00\x01\x02\x03\x04\x05\x06\x07\x08\x09"

with open('example.bin', 'wb') as f:
    f.write(line)

# %%
with open('example.bin','rb') as f:
    print(f.read())
# Out:
# b'\x00\x01\x02\x03\x04\x05\x06\x07\x08\t'
