# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt,pi
print(sqrt(25))
print(pi)
# Out:
# 5.0
# 3.141592653589793

# %%
# import all packages in once
from math import *
print(sqrt(81))
# Out:
# 9.0

# %%
# user built in packages for practice 

from package import maths

maths.factorial(5)

# maths.even_odd(4)
# Out:
# 120

# %%
from package.maths import mal, addition

print (mal(3,4))
print (addition(3,4))
# Out:
# 12
# 7
